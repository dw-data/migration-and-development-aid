# %%
import pandas as pd

# %%
#loading in the population data for the per capita calculation
population=pd.read_csv("Raw_Data/POP_RAW_coherent.csv", encoding='latin1')
population.head()
# Out:
#    Index    Variant               Region, subregion, country or area * Notes  \
# 0      1  Estimates                                              WORLD   NaN
# 1      2  Estimates                             More developed regions     a
# 2      3  Estimates                             Less developed regions     b
# 3      4  Estimates                          Least developed countries     c
# 4      5  Estimates  Less developed regions, excluding least develo...     d
#
#    Country code        1950        1951        1952        1953        1954  \
# 0           900   2 536 275   2 583 817   2 630 584   2 677 230   2 724 302
# 1           901     814 865     824 213     834 074     844 264     854 632
# 2           902   1 721 410   1 759 604   1 796 510   1 832 967   1 869 671
# 3           941     195 259     199 052     202 905     206 885     211 045
# 4           934   1 526 151   1 560 552   1 593 605   1 626 082   1 658 626
#
#       ...            2006        2007        2008        2009        2010  \
# 0     ...       6 623 848   6 706 419   6 789 771   6 873 741   6 958 169
# 1     ...       1 215 325   1 220 392   1 225 552   1 230 534   1 235 143
# 2     ...       5 408 523   5 486 027   5 564 219   5 643 207   5 723 027
# 3     ...         772 489     790 978     809 731     828 953     848 792
# 4     ...       4 636 034   4 695 048   4 754 488   4 814 254   4 874 235
#
#          2011        2012        2013        2014        2015
# 0   7 043 009   7 128 177   7 213 426   7 298 453   7 383 009
# 1   1 239 298   1 243 055   1 246 520   1 249 864   1 253 207
# 2   5 803 711   5 885 122   5 966 906   6 048 590   6 129 802
# 3     869 298     890 423     912 094     934 192     956 631
# 4   4 934 413   4 994 699   5 054 812   5 114 397   5 173 171
#
# [5 rows x 71 columns]

# %%
#setting the index to the country name, so that we can access each cell by country name and year
population=population.set_index('Region, subregion, country or area *')
population.head()
# Out:
#                                                     Index    Variant Notes  \
# Region, subregion, country or area *
# WORLD                                                   1  Estimates   NaN
# More developed regions                                  2  Estimates     a
# Less developed regions                                  3  Estimates     b
# Least developed countries                               4  Estimates     c
# Less developed regions, excluding least develop...      5  Estimates     d
#
#                                                     Country code        1950  \
# Region, subregion, country or area *
# WORLD                                                        900   2 536 275
# More developed regions                                       901     814 865
# Less developed regions                                       902   1 721 410
# Least developed countries                                    941     195 259
# Less developed regions, excluding least develop...           934   1 526 151
#
#                                                           1951        1952  \
# Region, subregion, country or area *
# WORLD                                                2 583 817   2 630 584
# More developed regions                                 824 213     834 074
# Less developed regions                               1 759 604   1 796 510
# Least developed countries                              199 052     202 905
# Less developed regions, excluding least develop...   1 560 552   1 593 605
#
#                                                           1953        1954  \
# Region, subregion, country or area *
# WORLD                                                2 677 230   2 724 302
# More developed regions                                 844 264     854 632
# Less developed regions                               1 832 967   1 869 671
# Least developed countries                              206 885     211 045
# Less developed regions, excluding least develop...   1 626 082   1 658 626
#
#                                                           1955     ...      \
# Region, subregion, country or area *                               ...
# WORLD                                                2 772 243     ...
# More developed regions                                 865 069     ...
# Less developed regions                               1 907 173     ...
# Least developed countries                              215 421     ...
# Less developed regions, excluding least develop...   1 691 752     ...
#
#                                                           2006        2007  \
# Region, subregion, country or area *
# WORLD                                                6 623 848   6 706 419
# More developed regions                               1 215 325   1 220 392
# Less developed regions                               5 408 523   5 486 027
# Least developed countries                              772 489     790 978
# Less developed regions, excluding least develop...   4 636 034   4 695 048
#
#                                                           2008        2009  \
# Region, subregion, country or area *
# WORLD                                                6 789 771   6 873 741
# More developed regions                               1 225 552   1 230 534
# Less developed regions                               5 564 219   5 643 207
# Least developed countries                              809 731     828 953
# Less developed regions, excluding least develop...   4 754 488   4 814 254
#
#                                                           2010        2011  \
# Region, subregion, country or area *
# WORLD                                                6 958 169   7 043 009
# More developed regions                               1 235 143   1 239 298
# Less developed regions                               5 723 027   5 803 711
# Least developed countries                              848 792     869 298
# Less developed regions, excluding least develop...   4 874 235   4 934 413
#
#                                                           2012        2013  \
# Region, subregion, country or area *
# WORLD                                                7 128 177   7 213 426
# More developed regions                               1 243 055   1 246 520
# Less developed regions                               5 885 122   5 966 906
# Least developed countries                              890 423     912 094
# Less developed regions, excluding least develop...   4 994 699   5 054 812
#
#                                                           2014        2015
# Region, subregion, country or area *
# WORLD                                                7 298 453   7 383 009
# More developed regions                               1 249 864   1 253 207
# Less developed regions                               6 048 590   6 129 802
# Least developed countries                              934 192     956 631
# Less developed regions, excluding least develop...   5 114 397   5 173 171
#
# [5 rows x 70 columns]

# %%
#checking if this form of accessing works
country='Zambia'
year='2007'
print(int(population.loc[country][year].replace(" ", ""))*1000)
# Out:
# 12726000

# %%
#loading in the data for dev aid for the last 20 years (ODA for all donors not only DAC/OECD)
ODAfromall=pd.read_csv("Raw_Data/ODAfromall.csv")

# %%
ODAfromall.head()
# Out:
#    RECIPIENT Recipient  DONOR              Donor  PART  \
# 0         71   Albania  20005  All Donors, Total     1
# 1         71   Albania  20005  All Donors, Total     1
# 2         71   Albania  20005  All Donors, Total     1
# 3         71   Albania  20005  All Donors, Total     1
# 4         71   Albania  20005  All Donors, Total     1
#
#                                 Part  AIDTYPE        Aid type DATATYPE  \
# 0  1 : Part I - Developing Countries      206  ODA: Total Net        D
# 1  1 : Part I - Developing Countries      206  ODA: Total Net        D
# 2  1 : Part I - Developing Countries      206  ODA: Total Net        D
# 3  1 : Part I - Developing Countries      206  ODA: Total Net        D
# 4  1 : Part I - Developing Countries      206  ODA: Total Net        D
#
#        Amount type  ...    Year  Unit Code       Unit PowerCode Code  \
# 0  Constant Prices  ...    1993        USD  US Dollar              6
# 1  Constant Prices  ...    1994        USD  US Dollar              6
# 2  Constant Prices  ...    1995        USD  US Dollar              6
# 3  Constant Prices  ...    1996        USD  US Dollar              6
# 4  Constant Prices  ...    1997        USD  US Dollar              6
#
#    PowerCode Reference Period Code  Reference Period   Value  Flag Codes  \
# 0   Millions                  2015              2015  373.79         NaN
# 1   Millions                  2015              2015  207.09         NaN
# 2   Millions                  2015              2015  210.32         NaN
# 3   Millions                  2015              2015  272.03         NaN
# 4   Millions                  2015              2015  215.06         NaN
#
#    Flags
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 21 columns]

# %%
#sort the data first by recipient and then by donor and year
ODAfromall=ODAfromall.sort_values(by=["Recipient","Donor","Year"])
testdata=ODAfromall
#testdata=testdata.head()
testdata
# Out:
#       RECIPIENT    Recipient  DONOR              Donor  PART  \
# 1286        625  Afghanistan  20005  All Donors, Total     1
# 3170        625  Afghanistan  20005  All Donors, Total     1
# 1287        625  Afghanistan  20005  All Donors, Total     1
# 3171        625  Afghanistan  20005  All Donors, Total     1
# 1288        625  Afghanistan  20005  All Donors, Total     1
# 3172        625  Afghanistan  20005  All Donors, Total     1
# 1289        625  Afghanistan  20005  All Donors, Total     1
# 3173        625  Afghanistan  20005  All Donors, Total     1
# 1290        625  Afghanistan  20005  All Donors, Total     1
# 3174        625  Afghanistan  20005  All Donors, Total     1
# 1291        625  Afghanistan  20005  All Donors, Total     1
# 3175        625  Afghanistan  20005  All Donors, Total     1
# 1292        625  Afghanistan  20005  All Donors, Total     1
# 3176        625  Afghanistan  20005  All Donors, Total     1
# 1293        625  Afghanistan  20005  All Donors, Total     1
# 3177        625  Afghanistan  20005  All Donors, Total     1
# 1294        625  Afghanistan  20005  All Donors, Total     1
# 3178        625  Afghanistan  20005  All Donors, Total     1
# 1295        625  Afghanistan  20005  All Donors, Total     1
# 3179        625  Afghanistan  20005  All Donors, Total     1
# 1296        625  Afghanistan  20005  All Donors, Total     1
# 3180        625  Afghanistan  20005  All Donors, Total     1
# 1297        625  Afghanistan  20005  All Donors, Total     1
# 3181        625  Afghanistan  20005  All Donors, Total     1
# 1298        625  Afghanistan  20005  All Donors, Total     1
# 3182        625  Afghanistan  20005  All Donors, Total     1
# 1299        625  Afghanistan  20005  All Donors, Total     1
# 3183        625  Afghanistan  20005  All Donors, Total     1
# 1300        625  Afghanistan  20005  All Donors, Total     1
# 3184        625  Afghanistan  20005  All Donors, Total     1
# ...         ...          ...    ...                ...   ...
# 834         265     Zimbabwe  20005  All Donors, Total     1
# 2718        265     Zimbabwe  20005  All Donors, Total     1
# 835         265     Zimbabwe  20005  All Donors, Total     1
# 2719        265     Zimbabwe  20005  All Donors, Total     1
# 836         265     Zimbabwe  20005  All Donors, Total     1
# 2720        265     Zimbabwe  20005  All Donors, Total     1
# 837         265     Zimbabwe  20005  All Donors, Total     1
# 2721        265     Zimbabwe  20005  All Donors, Total     1
# 838         265     Zimbabwe  20005  All Donors, Total     1
# 2722        265     Zimbabwe  20005  All Donors, Total     1
# 839         265     Zimbabwe  20005  All Donors, Total     1
# 2723        265     Zimbabwe  20005  All Donors, Total     1
# 840         265     Zimbabwe  20005  All Donors, Total     1
# 2724        265     Zimbabwe  20005  All Donors, Total     1
# 841         265     Zimbabwe  20005  All Donors, Total     1
# 2725        265     Zimbabwe  20005  All Donors, Total     1
# 842         265     Zimbabwe  20005  All Donors, Total     1
# 2726        265     Zimbabwe  20005  All Donors, Total     1
# 843         265     Zimbabwe  20005  All Donors, Total     1
# 2727        265     Zimbabwe  20005  All Donors, Total     1
# 844         265     Zimbabwe  20005  All Donors, Total     1
Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1287                        ODA: Total Net        D  Constant Prices  ...
# 3171  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1288                        ODA: Total Net        D  Constant Prices  ...
# 3172  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1289                        ODA: Total Net        D  Constant Prices  ...
# 3173  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1290                        ODA: Total Net        D  Constant Prices  ...
# 3174  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1291                        ODA: Total Net        D  Constant Prices  ...
# 3175  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1292                        ODA: Total Net        D  Constant Prices  ...
# 3176  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1293                        ODA: Total Net        D  Constant Prices  ...
# 3177  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1294                        ODA: Total Net        D  Constant Prices  ...
# 3178  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1295                        ODA: Total Net        D  Constant Prices  ...
# 3179  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1296                        ODA: Total Net        D  Constant Prices  ...
# 3180  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1297                        ODA: Total Net        D  Constant Prices  ...
# 3181  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1298                        ODA: Total Net        D  Constant Prices  ...
# 3182  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1299                        ODA: Total Net        D  Constant Prices  ...
# 3183  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 1300                        ODA: Total Net        D  Constant Prices  ...
# 3184  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# ...                                    ...      ...              ...  ...
# 834                         ODA: Total Net        D  Constant Prices  ...
# 2718  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 835                         ODA: Total Net        D  Constant Prices  ...
# 2719  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 836                         ODA: Total Net        D  Constant Prices  ...
# 2720  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 837                         ODA: Total Net        D  Constant Prices  ...
# 2721  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 838                         ODA: Total Net        D  Constant Prices  ...
# 2722  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 839                         ODA: Total Net        D  Constant Prices  ...
# 2723  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 840                         ODA: Total Net        D  Constant Prices  ...
# 2724  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 841                         ODA: Total Net        D  Constant Prices  ...
# 2725  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 842                         ODA: Total Net        D  Constant Prices  ...
# 2726  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 843                         ODA: Total Net        D  Constant Prices  ...
# 2727  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 844                         ODA: Total Net        D  Constant Prices  ...
# 2728  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 845                         ODA: Total Net        D  Constant Prices  ...
# 2729  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 846                         ODA: Total Net        D  Constant Prices  ...
# 2730  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 847                         ODA: Total Net        D  Constant Prices  ...
# 2731  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
# 848                         ODA: Total Net        D  Constant Prices  ...
# 2732  Memo: ODA Total, Gross disbursements        D  Constant Prices  ...
#
#       Year  Unit Code       Unit PowerCode Code  PowerCode  \
# 1286  1993        USD  US Dollar              6   Millions
# 3170  1993        USD  US Dollar              6   Millions
# 1287  1994        USD  US Dollar              6   Millions
# 3171  1994        USD  US Dollar              6   Millions
# 1288  1995        USD  US Dollar              6   Millions
# 3172  1995        USD  US Dollar              6   Millions
# 1289  1996        USD  US Dollar              6   Millions
# 3173  1996        USD  US Dollar              6   Millions
# 1290  1997        USD  US Dollar              6   Millions
# 3174  1997        USD  US Dollar              6   Millions
# 1291  1998        USD  US Dollar              6   Millions
# 3175  1998        USD  US Dollar              6   Millions
# 1292  1999        USD  US Dollar              6   Millions
# 3176  1999        USD  US Dollar              6   Millions
# 1293  2000        USD  US Dollar              6   Millions
# 3177  2000        USD  US Dollar              6   Millions
# 1294  2001        USD  US Dollar              6   Millions
# 3178  2001        USD  US Dollar              6   Millions
# 1295  2002        USD  US Dollar              6   Millions
# 3181                  2015              2015  2588.32         NaN    NaN
# 1298                  2015              2015  3159.70         NaN    NaN
# 3182                  2015              2015  3163.58         NaN    NaN
# 1299                  2015              2015  3194.76         NaN    NaN
# 3183                  2015              2015  3198.92         NaN    NaN
# 1300                  2015              2015  5026.85         NaN    NaN
# 3184                  2015              2015  5028.15         NaN    NaN
# ...                    ...               ...      ...         ...    ...
# 834                   2015              2015   226.12         NaN    NaN
# 2718                  2015              2015   260.36         NaN    NaN
# 835                   2015              2015   266.19         NaN    NaN
# 2719                  2015              2015   293.18         NaN    NaN
# 836                   2015              2015   225.37         NaN    NaN
# 2720                  2015              2015   242.54         NaN    NaN
# 837                   2015              2015   204.18         NaN    NaN
# 2721                  2015              2015   232.69         NaN    NaN
# 838                   2015              2015   397.19         NaN    NaN
# 2722                  2015              2015   408.19         NaN    NaN
# 839                   2015              2015   283.49         NaN    NaN
# 2723                  2015              2015   293.07         NaN    NaN
# 840                   2015              2015   462.69         NaN    NaN
# 2724                  2015              2015   463.05         NaN    NaN
# 841                   2015              2015   589.60         NaN    NaN
# 2725                  2015              2015   593.11         NaN    NaN
# 842                   2015              2015   734.43         NaN    NaN
# 2726                  2015              2015   734.55         NaN    NaN
# 843                   2015              2015   685.47         NaN    NaN
# 2727                  2015              2015   694.01         NaN    NaN
# 844                   2015              2015   655.02         NaN    NaN
# 2728                  2015              2015   659.82         NaN    NaN
# 845                   2015              2015   928.94         NaN    NaN
# 2729                  2015              2015   938.88         NaN    NaN
# 846                   2015              2015   759.35         NaN    NaN
# 2730                  2015              2015   783.50         NaN    NaN
# 847                   2015              2015   696.59         NaN    NaN
# 2731                  2015              2015   701.70         NaN    NaN
# 848                   2015              2015   788.29         NaN    NaN
# 2732                  2015              2015   815.16         NaN    NaN
#
# [6170 rows x 21 columns]

# %%
#create an empty dataframe for storing the results
emptyframe = pd.DataFrame(columns=["Recipient","Year","Money spent per capita"])

#iterate through the dataframe row by row
for index, row in testdata.iterrows():
    #if the donor is "all donors" and if the aid type is the oda total, gross
    if row["Donor"]=="All Donors, Total" and row["Aid type"]=="Memo: ODA Total, Gross disbursements" and row["Amount type"]=="Constant Prices":
        #then set the recipient variable to recipient of the row
        recipient=row["Recipient"]
        annus=str(row["Year"])
        try:
            #we divide the foreign aid transferred to this country by the population of this country
            cashpercap=row["Value"]*1000000/(int(population.loc[recipient][annus].replace(" ", ""))*1000)
            cash=row["Value"]*1000000
            #and append the name of the recipient, the year and the sum spent per capita
            df2 = pd.DataFrame([[recipient,annus,cash,cashpercap]], columns=["Recipient","Year","Overall Sum","Money spent per capita"])
            emptyframe=emptyframe.append(df2,ignore_index=True)
        except KeyError:
            continue

# %%
#sanity checks
emptyframe=emptyframe[["Recipient","Year","Overall Sum","Money spent per capita"]]
print(emptyframe.head())
# Out:
#      Recipient  Year  Overall Sum  Money spent per capita
# 0  Afghanistan  1993  312140000.0               20.678370
# 1  Afghanistan  1994  309160000.0               19.115810
# 2  Afghanistan  1995  254130000.0               14.861404
# 3  Afghanistan  1996  204950000.0               11.499186
# 4  Afghanistan  1997  306840000.0               16.692416

# %%
#dropping all NaNs
print(len(emptyframe))
emptyframe=emptyframe.dropna(axis=1, how='any')
print(len(emptyframe))
# Out:
# 3009
# 3009

# %%
#saving the dataframe with the data about cash spent per capita in each country per pyear 
emptyframe.to_csv("FinalData/AllRecipients_Yearly_ODA.csv", index=False)

# %%
#devaidcap=pd.read_csv("FinalData/AllRecipients_Yearly_ODA.csv")

#sorting again the dataframe by recipient and year
devaid=emptyframe.sort_values(by=["Recipient","Year"])

# %%
#sanity checks
devaid.head()
# Out:
#      Recipient  Year  Overall Sum  Money spent per capita
# 0  Afghanistan  1993  312140000.0               20.678370
# 1  Afghanistan  1994  309160000.0               19.115810
# 2  Afghanistan  1995  254130000.0               14.861404
# 3  Afghanistan  1996  204950000.0               11.499186
# 4  Afghanistan  1997  306840000.0               16.692416

# %%
#loading in the data
testdata=devaid

# %%
#now we run this script to calculate the average over three years as described in the paper
#first creating an emptydataframe to append the results of our calculations to
emptyframe3 = pd.DataFrame(columns=['Recipient','Report Year',"3yrAverage Money"])

#now we define for each column two variables that allow us to track
#the recipient, the year and the money from the previous year
#and the recipient, the year and the money from the year before 
previousrecipient="0"
recipient2="0"

previousyear=0
year2=0

previousmoney=0
money2=0

previousmoneypercap=0
moneypercap2=0

#now we iterate through the dataframe
for index, row in testdata.iterrows():
    #and pick up the recipient, the year and the money received for the current row
    recipient=row[0]
    year=int(row[1])
    money=row[2]
    moneypercap=row[3]
    
    #if the number of current year is bigger than from the previous year
    #and the previous year is one year bigger than the year before
    if (year-1==previousyear)and(previousyear-1==year2):
        #and the recipient has been the same through all of these years
        if (recipient==previousrecipient)and(previousrecipient==recipient2):
            
            #we calculate the average sum of devaid built from the current year, the previous year and the year before
            average=(money+previousmoney+money2)/3
            averagepercap=(moneypercap+previousmoneypercap+moneypercap2)/3
            #and define the reportyear as the year after
            reportyear=int(year+1)
            
            #and then we add the recipient, the reportyear and the average of these three years to our dataframe
            df2 = pd.DataFrame([[recipient,reportyear,average, averagepercap]], columns=['Recipient','Report Year',"3yrAverage Money","3yrAverage Money per cap"])
            emptyframe3=emptyframe3.append(df2,ignore_index=True)
            
            #and then we redefine for these variable by shifting them
            #the recipient from two years ago becomes the one from the previous year
            #the previous recipient becomes the one from the current row
            #and so on
            recipient2=previousrecipient
            previousrecipient=recipient

            year2=previousyear
            previousyear=year

            money2=previousmoney
            previousmoney=money
            
            moneypercap2=previousmoneypercap
            previousmoneypercap=moneypercap
        else:
            pass
    
    else:
        pass
        #and we do this shift/exchange also when the if statement was not true
        recipient2=previousrecipient
        previousrecipient=recipient

        year2=previousyear
        previousyear=year

        moneypercap2=previousmoneypercap
        previousmoneypercap=moneypercap

# %%
#sanity checks
emptyframe3=emptyframe3[["Recipient","Report Year","3yrAverage Money","3yrAverage Money per cap"]]
emptyframe3.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap
# 0  Afghanistan       1996.0      8.471000e+07                 18.218528
# 1  Afghanistan       1997.0      1.530267e+08                 15.158800
# 2  Afghanistan       1998.0      2.553067e+08                 14.351002
# 3  Afghanistan       1999.0      2.446233e+08                 13.321431
# 4  Afghanistan       2000.0      2.410600e+08                 12.825481

# %%
emptyframe3.tail()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap
# 2734  Zimbabwe       2012.0      6.961267e+08                 49.439197
# 2735  Zimbabwe       2013.0      7.642367e+08                 52.984451
# 2736  Zimbabwe       2014.0      7.940667e+08                 53.908793
# 2737  Zimbabwe       2015.0      8.080267e+08                 53.797866
# 2738  Zimbabwe       2016.0      7.667867e+08                 49.746529

# %%
emptyframe3.to_csv("FinalData/AllRecipients_3YearAVG_ODA.csv")
devaid3yrs=emptyframe3

# %%
#now we load the file of migration of the last 20 years in OECD countries
#so this is a statistic for each OECD country noting how many migrants from each country it has uptaken in each year
rawfilemig=pd.read_csv("Raw_Data/MIG_RAW_20yrs_coherent.csv", encoding="latin1")

# %%
rawfilemig.head()
# Out:
#   ÈÀ"CO2" Country of birth/nationality  VAR  \
# 0      AFG                  Afghanistan  B11
# 1      AFG                  Afghanistan  B11
# 2      AFG                  Afghanistan  B11
# 3      AFG                  Afghanistan  B11
# 4      AFG                  Afghanistan  B11
#
#                                        Variable  GEN Gender  COU    Country  \
# 0  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 1  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 2  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 3  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 4  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
#
#     YEA  Year  Value Flag Codes Flags
# 0  1997  1997  368.0        NaN   NaN
# 1  1998  1998  620.0        NaN   NaN
# 2  1999  1999  852.0        NaN   NaN
# 3  2000  2000  887.0        NaN   NaN
# 4  2001  2001  456.0        NaN   NaN

# %%
#we first sort the dataframe by the country of birth, then the country they migrated to and then by the year
rawfilemig=rawfilemig.sort_values(by=['Country of birth/nationality', 'Year', 'Country'])

# %%
#we load this data in
testdata=rawfilemig
#testdata=testdata.head()
testdata
# Out:
#       ÈÀ"CO2" Country of birth/nationality  VAR  \
# 45         AFG                  Afghanistan  B11
# 78         AFG                  Afghanistan  B11
# 117        AFG                  Afghanistan  B11
# 137        AFG                  Afghanistan  B11
# 231        AFG                  Afghanistan  B11
# 289        AFG                  Afghanistan  B11
# 351        AFG                  Afghanistan  B11
# 377        AFG                  Afghanistan  B11
# 0          AFG                  Afghanistan  B11
# 46         AFG                  Afghanistan  B11
# 79         AFG                  Afghanistan  B11
# 98         AFG                  Afghanistan  B11
# 118        AFG                  Afghanistan  B11
# 138        AFG                  Afghanistan  B11
# 232        AFG                  Afghanistan  B11
# 290        AFG                  Afghanistan  B11
# 332        AFG                  Afghanistan  B11
# 352        AFG                  Afghanistan  B11
# 378        AFG                  Afghanistan  B11
# 389        AFG                  Afghanistan  B11
# 1          AFG                  Afghanistan  B11
# 19         AFG                  Afghanistan  B11
# 47         AFG                  Afghanistan  B11
# 80         AFG                  Afghanistan  B11
# 99         AFG                  Afghanistan  B11
# 119        AFG                  Afghanistan  B11
# 139        AFG                  Afghanistan  B11
# 436        AFG                  Afghanistan  B11
# 233        AFG                  Afghanistan  B11
# 291        AFG                  Afghanistan  B11
# ...        ...                          ...  ...
# 84744      ZWE                     Zimbabwe  B11
# 84775      ZWE                     Zimbabwe  B11
# 84402      ZWE                     Zimbabwe  B11
# 84420      ZWE                     Zimbabwe  B11
# 84427      ZWE                     Zimbabwe  B11
# 84447      ZWE                     Zimbabwe  B11
# 84788      ZWE                     Zimbabwe  B11
# 84459      ZWE                     Zimbabwe  B11
# 84478      ZWE                     Zimbabwe  B11
# 84800      ZWE                     Zimbabwe  B11
# 84497      ZWE                     Zimbabwe  B11
# 84517      ZWE                     Zimbabwe  B11
# 84537      ZWE                     Zimbabwe  B11
# 84552      ZWE                     Zimbabwe  B11
# 84569      ZWE                     Zimbabwe  B11
# 84585      ZWE                     Zimbabwe  B11
# 84595      ZWE                     Zimbabwe  B11
# 84611      ZWE                     Zimbabwe  B11
# 86575      ZWE                     Zimbabwe  B11
# 84631      ZWE                     Zimbabwe  B11
# 84651      ZWE                     Zimbabwe  B11
# 84667      ZWE                     Zimbabwe  B11
# 84687      ZWE                     Zimbabwe  B11
# 84697      ZWE                     Zimbabwe  B11
# 84704      ZWE                     Zimbabwe  B11
# 84723      ZWE                     Zimbabwe  B11
# 84739      ZWE                     Zimbabwe  B11
# 84745      ZWE                     Zimbabwe  B11
# 84757      ZWE                     Zimbabwe  B11
# 84776      ZWE                     Zimbabwe  B11
#
#                                            Variable  GEN Gender  COU  \
# 45     Inflows of foreign population by nationality  TOT  Total  CAN
# 78     Inflows of foreign population by nationality  TOT  Total  DNK
# 117    Inflows of foreign population by nationality  TOT  Total  FRA
# 137    Inflows of foreign population by nationality  TOT  Total  DEU
# 231    Inflows of foreign population by nationality  TOT  Total  LUX
# 289    Inflows of foreign population by nationality  TOT  Total  NOR
# 351    Inflows of foreign population by nationality  TOT  Total  SWE
# 377    Inflows of foreign population by nationality  TOT  Total  TUR
# 0      Inflows of foreign population by nationality  TOT  Total  AUS
# 46     Inflows of foreign population by nationality  TOT  Total  CAN
# 79     Inflows of foreign population by nationality  TOT  Total  DNK
# 98     Inflows of foreign population by nationality  TOT  Total  FIN
# 118    Inflows of foreign population by nationality  TOT  Total  FRA
# 138    Inflows of foreign population by nationality  TOT  Total  DEU
# 232    Inflows of foreign population by nationality  TOT  Total  LUX
# 290    Inflows of foreign population by nationality  TOT  Total  NOR
# 332    Inflows of foreign population by nationality  TOT  Total  ESP
# 352    Inflows of foreign population by nationality  TOT  Total  SWE
# 378    Inflows of foreign population by nationality  TOT  Total  TUR
# 389    Inflows of foreign population by nationality  TOT  Total  USA
# 1      Inflows of foreign population by nationality  TOT  Total  AUS
# 19     Inflows of foreign population by nationality  TOT  Total  AUT
# 47     Inflows of foreign population by nationality  TOT  Total  CAN
# 80     Inflows of foreign population by nationality  TOT  Total  DNK
# 99     Inflows of foreign population by nationality  TOT  Total  FIN
# 119    Inflows of foreign population by nationality  TOT  Total  FRA
# 139    Inflows of foreign population by nationality  TOT  Total  DEU
# 436    Inflows of foreign population by nationality  TOT  Total  ISR
# 233    Inflows of foreign population by nationality  TOT  Total  LUX
# 291    Inflows of foreign population by nationality  TOT  Total  NOR
# ...                                             ...  ...    ...  ...
# 84744  Inflows of foreign population by nationality  TOT  Total  CHE
# 84775  Inflows of foreign population by nationality  TOT  Total  USA
# 84402  Inflows of foreign population by nationality  TOT  Total  AUS
# 84420  Inflows of foreign population by nationality  TOT  Total  AUT
# 84427  Inflows of foreign population by nationality  TOT  Total  BEL
# 84447  Inflows of foreign population by nationality  TOT  Total  CAN
# 84788  Inflows of foreign population by nationality  TOT  Total  CHL
# 84459  Inflows of foreign population by nationality  TOT  Total  CZE
# 84478  Inflows of foreign population by nationality  TOT  Total  DNK
# 84800  Inflows of foreign population by nationality  TOT  Total  EST
# 84497  Inflows of foreign population by nationality  TOT  Total  FIN
# 84517  Inflows of foreign population by nationality  TOT  Total  FRA
# 84537  Inflows of foreign population by nationality  TOT  Total  DEU
# 84552  Inflows of foreign population by nationality  TOT  Total  HUN
# 84569  Inflows of foreign population by nationality  TOT  Total  ISL
# 84585  Inflows of foreign population by nationality  TOT  Total  ITA
# 84595  Inflows of foreign population by nationality  TOT  Total  JPN
# 84611  Inflows of foreign population by nationality  TOT  Total  KOR
# 86575  Inflows of foreign population by nationality  TOT  Total  LVA
# 84631  Inflows of foreign population by nationality  TOT  Total  LUX
# 84651  Inflows of foreign population by nationality  TOT  Total  NLD
# 84667  Inflows of foreign population by nationality  TOT  Total  NZL
# 84687  Inflows of foreign population by nationality  TOT  Total  NOR
# 84697  Inflows of foreign population by nationality  TOT  Total  POL
# 84704  Inflows of foreign population by nationality  TOT  Total  SVK
# 84723  Inflows of foreign population by nationality  TOT  Total  ESP
# 84739  Inflows of foreign population by nationality  TOT  Total  SWE
# 84745  Inflows of foreign population by nationality  TOT  Total  CHE
# 84757  Inflows of foreign population by nationality  TOT  Total  GBR
# 84776  Inflows of foreign population by nationality  TOT  Total  USA
#
#                Country   YEA  Year   Value Flag Codes Flags
# 45              Canada  1996  1996  2010.0        NaN   NaN
# 78             Denmark  1996  1996   335.0        NaN   NaN
# 117             France  1996  1996   131.0        NaN   NaN
# 137            Germany  1996  1996  7019.0        NaN   NaN
# 231         Luxembourg  1996  1996     1.0        NaN   NaN
# 289             Norway  1996  1996     4.0        NaN   NaN
# 351             Sweden  1996  1996   570.0        NaN   NaN
# 377             Turkey  1996  1996  2695.0        NaN   NaN
# 0            Australia  1997  1997   368.0        NaN   NaN
# 46              Canada  1997  1997  2115.0        NaN   NaN
# 79             Denmark  1997  1997   319.0        NaN   NaN
# 98             Finland  1997  1997     8.0        NaN   NaN
# 118             France  1997  1997    92.0        NaN   NaN
# 138            Germany  1997  1997  5526.0        NaN   NaN
# 232         Luxembourg  1997  1997     1.0        NaN   NaN
# 290             Norway  1997  1997    34.0        NaN   NaN
# 332              Spain  1997  1997     2.0        NaN   NaN
# 352             Sweden  1997  1997   612.0        NaN   NaN
# 378             Turkey  1997  1997  2933.0        NaN   NaN
# 389      United States  1997  1997  1127.0        NaN   NaN
# 1            Australia  1998  1998   620.0        NaN   NaN
# 19             Austria  1998  1998   198.0        NaN   NaN
# 47              Canada  1998  1998  1583.0        NaN   NaN
# 80             Denmark  1998  1998   443.0        NaN   NaN
# 99             Finland  1998  1998    15.0        NaN   NaN
# 119             France  1998  1998    87.0        NaN   NaN
# 139            Germany  1998  1998  4768.0        NaN   NaN
# 436             Israel  1998  1998     0.0        NaN   NaN
# 233         Luxembourg  1998  1998     0.0        NaN   NaN
# 291             Norway  1998  1998    42.0        NaN   NaN
# ...                ...   ...   ...     ...        ...   ...
# 84744      Switzerland  2014  2014    28.0        NaN   NaN
# 84775    United States  2014  2014   797.0        NaN   NaN
# 84402        Australia  2015  2015   806.0        NaN   NaN
# 84420          Austria  2015  2015    14.0        NaN   NaN
# 84427          Belgium  2015  2015    31.0        NaN   NaN
# 84447           Canada  2015  2015   238.0        NaN   NaN
# 84788            Chile  2015  2015     1.0        NaN   NaN
# 84459   Czech Republic  2015  2015     6.0        NaN   NaN
# 84478          Denmark  2015  2015     8.0        NaN   NaN
# 84800          Estonia  2015  2015     0.0        NaN   NaN
# 84497          Finland  2015  2015     5.0        NaN   NaN
# 84517           France  2015  2015    17.0        NaN   NaN
# 84537          Germany  2015  2015   204.0        NaN   NaN
# 84552          Hungary  2015  2015     6.0        NaN   NaN
# 84569          Iceland  2015  2015     1.0        NaN   NaN
# 84585            Italy  2015  2015    11.0        NaN   NaN
# 84595            Japan  2015  2015   196.0        NaN   NaN
# 84611            Korea  2015  2015    40.0        NaN   NaN
# 86575           Latvia  2015  2015     0.0        NaN   NaN
# 84631       Luxembourg  2015  2015     4.0        NaN   NaN
# 84651      Netherlands  2015  2015    67.0        NaN   NaN
# 84667      New Zealand  2015  2015    62.0        NaN   NaN
# 84687           Norway  2015  2015    14.0        NaN   NaN
# 84697           Poland  2015  2015    19.0        NaN   NaN
# 84704  Slovak Republic  2015  2015     1.0        NaN   NaN
# 84723            Spain  2015  2015    12.0        NaN   NaN
# 84739           Sweden  2015  2015    25.0        NaN   NaN
# 84745      Switzerland  2015  2015    35.0        NaN   NaN
# 84757   United Kingdom  2015  2015  1000.0        NaN   NaN
# 84776    United States  2015  2015   779.0        NaN   NaN
#
# [86769 rows x 13 columns]

# %%
#again we define an empty dataframe
emptyframe2 = pd.DataFrame(columns=['Country of Birth',"Destination","Emigration sum",'Emigration per cap'])
            
counter=0
#and now we iterate through the dataframe
for index, row in testdata.iterrows():
    counter+=1
    #this is just a simple progress counter
    if (counter%2000==0):
        print(counter)
    #only when the variable is about the inflow we process the data
    if row[3]=="Inflows of foreign population by nationality":
        #we set the birthcountry variable on the "Country of birth/nationality" value of the row and annus to the row's year
        birthcountry=row[1]
        annus=str(row["Year"])
        #we set the migdestination variable on the "Country" value of the row, so the country that has taken up the migrants
        migdestination=row["Country"]
        try:
            #now we dividee the migration number by the population
            mig=row["Value"]
            migpercap=row["Value"]/(int(population.loc[birthcountry][annus].replace(" ", ""))*1000)
            #and append all three variables to the dataframe
            df2 = pd.DataFrame([[birthcountry,annus, migdestination,mig,migpercap]], columns=['Country of Birth',"Year","Destination","Emigration sum",'Emigration per cap'])
            emptyframe2=emptyframe2.append(df2,ignore_index=True)
       
        except KeyError:
                pass
# Out:
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000
# 82000
# 84000
# 86000

# %%
emptyframe2
# Out:
#       Country of Birth      Destination  Emigration per cap  Emigration sum  \
# 0          Afghanistan           Canada        1.127756e-04          2010.0
# 1          Afghanistan          Denmark        1.879594e-05           335.0
# 2          Afghanistan           France        7.350053e-06           131.0
# 3          Afghanistan          Germany        3.938170e-04          7019.0
# 4          Afghanistan       Luxembourg        5.610728e-08             1.0
# 5          Afghanistan           Norway        2.244291e-07             4.0
# 6          Afghanistan           Sweden        3.198115e-05           570.0
# 7          Afghanistan           Turkey        1.512091e-04          2695.0
# 8          Afghanistan        Australia        2.001958e-05           368.0
# 9          Afghanistan           Canada        1.150582e-04          2115.0
# 10         Afghanistan          Denmark        1.735393e-05           319.0
# 11         Afghanistan          Finland        4.352084e-07             8.0
# 12         Afghanistan           France        5.004896e-06            92.0
# 13         Afghanistan          Germany        3.006202e-04          5526.0
# 14         Afghanistan       Luxembourg        5.440104e-08             1.0
# 15         Afghanistan           Norway        1.849636e-06            34.0
# 16         Afghanistan            Spain        1.088021e-07             2.0
# 17         Afghanistan           Sweden        3.329344e-05           612.0
# 18         Afghanistan           Turkey        1.595583e-04          2933.0
# 19         Afghanistan    United States        6.130998e-05          1127.0
# 20         Afghanistan        Australia        3.286684e-05           620.0
# 21         Afghanistan          Austria        1.049618e-05           198.0
# 22         Afghanistan           Canada        8.391645e-05          1583.0
# 23         Afghanistan          Denmark        2.348388e-05           443.0
# 24         Afghanistan          Finland        7.951654e-07            15.0
# 25         Afghanistan           France        4.611959e-06            87.0
# 26         Afghanistan          Germany        2.527566e-04          4768.0
# 27         Afghanistan           Israel        0.000000e+00             0.0
# 28         Afghanistan       Luxembourg        0.000000e+00             0.0
# 29         Afghanistan           Norway        2.226463e-06            42.0
# ...                ...              ...                 ...             ...
# 80284         Zimbabwe      Switzerland        1.816766e-06            28.0
# 80285         Zimbabwe    United States        5.171295e-05           797.0
# 80286         Zimbabwe        Australia        5.108703e-05           806.0
# 80287         Zimbabwe          Austria        8.873677e-07            14.0
# 80288         Zimbabwe          Belgium        1.964886e-06            31.0
# 80289         Zimbabwe           Canada        1.508525e-05           238.0
# 80290         Zimbabwe            Chile        6.338341e-08             1.0
# 80291         Zimbabwe   Czech Republic        3.803004e-07             6.0
# 80292         Zimbabwe          Denmark        5.070672e-07             8.0
# 80293         Zimbabwe          Estonia        0.000000e+00             0.0
# 80294         Zimbabwe          Finland        3.169170e-07             5.0
# 80295         Zimbabwe           France        1.077518e-06            17.0
# 80296         Zimbabwe          Germany        1.293021e-05           204.0
# 80297         Zimbabwe          Hungary        3.803004e-07             6.0
# 80298         Zimbabwe          Iceland        6.338341e-08             1.0
# 80299         Zimbabwe            Italy        6.972175e-07            11.0
# 80300         Zimbabwe            Japan        1.242315e-05           196.0
# 80301         Zimbabwe            Korea        2.535336e-06            40.0
# 80302         Zimbabwe           Latvia        0.000000e+00             0.0
# 80303         Zimbabwe       Luxembourg        2.535336e-07             4.0
# 80304         Zimbabwe      Netherlands        4.246688e-06            67.0
# 80305         Zimbabwe      New Zealand        3.929771e-06            62.0
# 80306         Zimbabwe           Norway        8.873677e-07            14.0
# 80307         Zimbabwe           Poland        1.204285e-06            19.0
# 80308         Zimbabwe  Slovak Republic        6.338341e-08             1.0
# 80309         Zimbabwe            Spain        7.606009e-07            12.0
# 80310         Zimbabwe           Sweden        1.584585e-06            25.0
# 80311         Zimbabwe      Switzerland        2.218419e-06            35.0
# 80312         Zimbabwe   United Kingdom        6.338341e-05          1000.0
# 80313         Zimbabwe    United States        4.937567e-05           779.0
#
#        Year
# 0      1996
# 1      1996
# 2      1996
# 3      1996
# 4      1996
# 5      1996
# 6      1996
# 7      1996
# 8      1997
# 9      1997
# 10     1997
# 11     1997
# 12     1997
# 13     1997
# 14     1997
# 15     1997
# 16     1997
# 17     1997
# 18     1997
# 19     1997
# 20     1998
# 21     1998
# 22     1998
# 23     1998
# 24     1998
# 25     1998
# 26     1998
# 27     1998
# 28     1998
# 29     1998
# ...     ...
# 80284  2014
# 80285  2014
# 80286  2015
# 80287  2015
# 80288  2015
# 80289  2015
# 80290  2015
# 80291  2015
# 80292  2015
# 80293  2015
# 80294  2015
# 80295  2015
# 80296  2015
# 80297  2015
# 80298  2015
# 80299  2015
# 80300  2015
# 80301  2015
# 80302  2015
# 80303  2015
# 80304  2015
# 80305  2015
# 80306  2015
# 80307  2015
# 80308  2015
# 80309  2015
# 80310  2015
# 80311  2015
# 80312  2015
# 80313  2015
#
# [80314 rows x 5 columns]

# %%
migpercap=emptyframe2

# %%
#and then we save this dataframe that consists of all bilateral migrations as an average over the years
emptyframe2.to_csv("FinalData/AllMig_bilateral_abs_Yearly.csv",index=False)

# %%
#now we use this newly created dataframe to calculate the overall outflow of migrants from any country into OECD countries
testdata=emptyframe2
testdata=testdata.sort_values(by=["Country of Birth","Year"])
testdata.head()
#testdata=testdata.head(1000)
# Out:
#   Country of Birth Destination  Emigration per cap  Emigration sum  Year
# 0      Afghanistan      Canada        1.127756e-04          2010.0  1996
# 1      Afghanistan     Denmark        1.879594e-05           335.0  1996
# 2      Afghanistan      France        7.350053e-06           131.0  1996
# 3      Afghanistan     Germany        3.938170e-04          7019.0  1996
# 4      Afghanistan  Luxembourg        5.610728e-08             1.0  1996

# %%
#again we create an emptydataframe
emptyframe3 = pd.DataFrame(columns=['Country of Birth','Emigration per cap over all OECD','Emigration sum over all OECD countries',"Year"])
#we set the variables to default values
previousbirth="0"
previousannus="0"
sumOECD=0
sumOECDpercap=0
counter=0
#we iterate through the dataframe
for index, row in testdata.iterrows():
    counter+=1
    if (counter%2000==0):
        print(counter)
    #in each row the country of birth variable is taken from the rows 0th column
    birthcountry=row[0]
    #and the row's year
    annus=row[4]
    #if the previous birth country was not the default value and is not the current birth country
    #or the year is not the year of this row is different from the row before
    if (previousbirth != "0" and previousbirth!=birthcountry)or(previousannus != "0" and previousannus!=annus):
        #we then append the country of birth, the year and the sum of emigration to the dataframe
        df2 = pd.DataFrame([[previousbirth,sumOECDpercap,sumOECD,previousannus]], columns=['Country of Birth','Emigration per cap over all OECD','Emigration sum over all OECD countries',"Year"])
        emptyframe3=emptyframe3.append(df2,ignore_index=True)
        #we reset the number of migrants to zero and then add the value of the current row
        sumOECD=0
        sumOECD+=row["Emigration sum"]
        sumOECDpercap=0
        sumOECDpercap+=row["Emigration per cap"]
        #and we change the previousbirth variable to the one of the current country
        #and the previous year to the one of the current yrow
        previousbirth=birthcountry
        previousannus=annus
    #if the previous row and the current row have the same birthcountry then
    else:
        #we keep adding the value of emigration to the sum
        sumOECD+=row["Emigration sum"]
        sumOECDpercap+=row["Emigration per cap"]
        #and we also change the previousbirth variable to the one of the current country
        previousbirth=birthcountry
        previousannus=annus
# Out:
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000

# %%
#now we rename this new dataframe and rename the column to prepare a merge
migoverall=emptyframe3.rename(index=str, columns={"Country of Birth": "Recipient"})
#and save the migration figures
migoverall.to_csv("FinalData/migToOECD_avg_yearly.csv", index=False)
print(len(migoverall))
migoverall.head()
# Out:
# 3859
#      Recipient  Emigration per cap over all OECD  \
# 0  Afghanistan                          0.000716
# 1  Afghanistan                          0.000715
# 2  Afghanistan                          0.000645
# 3  Afghanistan                          0.000613
# 4  Afghanistan                          0.000824
#
#    Emigration sum over all OECD countries  Year
# 0                                 12765.0  1996
# 1                                 13137.0  1997
# 2                                 12173.0  1998
# 3                                 11885.0  1999
# 4                                 16550.0  2000

# %%
#migoverall=pd.read_csv("migToOECD_avg_yearly.csv")

# %%
migoverall.tail()
# Out:
#      Recipient  Emigration per cap over all OECD  \
# 3854  Zimbabwe                          0.000311
# 3855  Zimbabwe                          0.000315
# 3856  Zimbabwe                          0.000349
# 3857  Zimbabwe                          0.000207
# 3858  Zimbabwe                          0.000169
#
#       Emigration sum over all OECD countries  Year
# 3854                                  4377.0  2010
# 3855                                  4538.0  2011
# 3856                                  5134.0  2012
# 3857                                  3116.0  2013
# 3858                                  2608.0  2014

# %%
#we load in the data for each country and its migration per capita
migoverall=migoverall.sort_values(by=["Recipient", "Year"])
testdata=migoverall

# %%
#and now we also calculate three year averages
emptyframe3 = pd.DataFrame(columns=['Recipient','Report Year',"3yrAverage Migration per Cap","3yrAverage Migration"])
#We set up some variables that should store what was in the row before and the row even before that
previousrecipient="0"
recipient2="0"

previousyear=0
year2=0

previousmig=0
mig2=0

previousmigcap=0
migcap2=0

#we iteratre through the dataframe
for index, row in testdata.iterrows():
    #and get the recipient, the year and the number of migrants per capita
    recipient=row[0]
    year=int(row[3])
    migcap=row[1]
    mig=row[2]
    
    #we check whether we have three continous years
    #and the same country
    if (year-1==previousyear)and(previousyear-1==year2):
        if (recipient==previousrecipient)and(previousrecipient==recipient2):
            #then we calculate the 3year-average
            averagecap=(migcap+previousmigcap+migcap2)/3
            average=(mig+previousmig+mig2)/3
            #and add for the report year 1 year
            reportyear=int(year+1)
            #then we append the variables to the dataframe
            df2 = pd.DataFrame([[recipient,reportyear,averagecap,average]], columns=['Recipient','Report Year',"3yrAverage Migration per Cap","3yrAverage Migration"])
            emptyframe3=emptyframe3.append(df2,ignore_index=True)
            
            #we shift all variables by one row/year
            recipient2=previousrecipient
            previousrecipient=recipient

            year2=previousyear
            previousyear=year
            
            migcap2=previousmigcap
            previousmigcap=migcap
            
            mig2=previousmig
            previousmig=mig
        else:
            pass
    
    else:
        pass
        #we shift all variables by one row/year

        recipient2=previousrecipient
        previousrecipient=recipient

        year2=previousyear
        previousyear=year
        
        migcap2=previousmigcap
        previousmigcap=migcap

        mig2=previousmig
        previousmig=mig

# %%
emptyframe3.head()
# Out:
#      Recipient  Report Year  3yrAverage Migration per Cap  \
# 0  Afghanistan       1999.0                      0.000692
# 1  Afghanistan       2000.0                      0.000657
# 2  Afghanistan       2001.0                      0.000694
# 3  Afghanistan       2002.0                      0.000794
# 4  Afghanistan       2003.0                      0.000820
#
#    3yrAverage Migration
# 0          12691.666667
# 1          12398.333333
# 2          13536.000000
# 3          16096.000000
# 4          17182.000000

# %%
#and now we save this three year average of migration
emptyframe3.to_csv("FinalData/AllMig_3YearAVG_absolute.csv")

# %%
#and define it as the migration over 3 years
mig3yrs=emptyframe3
mig3yrs.head()
# Out:
#      Recipient  Report Year  3yrAverage Migration per Cap  \
# 0  Afghanistan       1999.0                      0.000692
# 1  Afghanistan       2000.0                      0.000657
# 2  Afghanistan       2001.0                      0.000694
# 3  Afghanistan       2002.0                      0.000794
# 4  Afghanistan       2003.0                      0.000820
#
#    3yrAverage Migration
# 0          12691.666667
# 1          12398.333333
# 2          13536.000000
# 3          16096.000000
# 4          17182.000000

# %%
#this is the average migration just for one year
migoverall.head()
# Out:
#      Recipient  Emigration per cap over all OECD  \
# 0  Afghanistan                          0.000716
# 1  Afghanistan                          0.000715
# 2  Afghanistan                          0.000645
# 3  Afghanistan                          0.000613
# 4  Afghanistan                          0.000824
#
#    Emigration sum over all OECD countries  Year
# 0                                 12765.0  1996
# 1                                 13137.0  1997
# 2                                 12173.0  1998
# 3                                 11885.0  1999
# 4                                 16550.0  2000

# %%
#and this is the sum of dev aid spent in 3year periods
devaid3yrs.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap
# 0  Afghanistan       1996.0      8.471000e+07                 18.218528
# 1  Afghanistan       1997.0      1.530267e+08                 15.158800
# 2  Afghanistan       1998.0      2.553067e+08                 14.351002
# 3  Afghanistan       1999.0      2.446233e+08                 13.321431
# 4  Afghanistan       2000.0      2.410600e+08                 12.825481

# %%
#we had to rename the Year to Report Year and change it to floar for the next merge 
migoverall=migoverall.rename(columns={"Year":"Report Year"})
migoverall["Report Year"]=migoverall["Report Year"].astype(float)
migoverall.head()
# Out:
#      Recipient  Emigration per cap over all OECD  \
# 0  Afghanistan                          0.000716
# 1  Afghanistan                          0.000715
# 2  Afghanistan                          0.000645
# 3  Afghanistan                          0.000613
# 4  Afghanistan                          0.000824
#
#    Emigration sum over all OECD countries  Report Year
# 0                                 12765.0       1996.0
# 1                                 13137.0       1997.0
# 2                                 12173.0       1998.0
# 3                                 11885.0       1999.0
# 4                                 16550.0       2000.0

# %%
#we now merge two dataframe by the column "Recipient" and only values are preserved that exist in both dataframes
#this is the merge between 3yr average for dev aid and the migration by year
result31=pd.merge(devaid3yrs,migoverall, on=["Recipient","Report Year"], how="inner")

# %%
#we now merge two dataframe by the column "Recipient" and only values are preserved that exist in both dataframes
#this is the merge between 3yr average for dev aid and the 3yr average of migration by year
result33=pd.merge(devaid3yrs,mig3yrs, on=["Recipient","Report Year"], how="inner")

# %%
#we get rid of all zero values and all NaN
result31=result31[(result31 != 0).all(1)]
result31=result31.dropna()
len(result31)
# Out:
# 2549

# %%
result33=result33[(result33 != 0).all(1)]
result33=result33.dropna()
len(result33)
# Out:
# 2277

# %%
result31.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0  Afghanistan       1996.0      8.471000e+07                 18.218528
# 1  Afghanistan       1997.0      1.530267e+08                 15.158800
# 2  Afghanistan       1998.0      2.553067e+08                 14.351002
# 3  Afghanistan       1999.0      2.446233e+08                 13.321431
# 4  Afghanistan       2000.0      2.410600e+08                 12.825481
#
#    Emigration per cap over all OECD  Emigration sum over all OECD countries
# 0                          0.000716                                 12765.0
# 1                          0.000715                                 13137.0
# 2                          0.000645                                 12173.0
# 3                          0.000613                                 11885.0
# 4                          0.000824                                 16550.0

# %%
#and  save the results
result33.to_csv("FinalData/Migration3VSMoney3YearAVG_abs_ODA.csv", index=False)
result31.to_csv("FinalData/Migration1VSMoney3YearAVG_abs_ODA.csv", index=False)

# %%
#now we want to add a classification of continenty for each country
asia=pd.read_csv("Raw_data/Continents/asia.csv")
asia=asia["ASIA"].tolist()
europe=pd.read_csv("Raw_data/Continents/europe.csv")
europe=europe["EUROPE"].tolist()
africa=pd.read_csv("Raw_data/Continents/africa.csv", encoding='latin1')
africa=africa["AFRICA"].tolist()
carribeans=pd.read_csv("Raw_data/Continents/carribeans.csv", encoding='latin1')
carribeans=carribeans["Caribbean"].tolist()
americas=pd.read_csv("Raw_data/Continents/americas.csv", encoding='latin1')
americas=americas["Central America"].tolist()
oceania=pd.read_csv("Raw_data/Continents/oceania.csv", encoding='latin1')
oceania=oceania["OCEANIA"].tolist()
oceania
# Out:
# ['Australia/New Zealand',
#  'Australia',
#  'New Zealand',
#  'Melanesia',
#  'Fiji',
#  'New Caledonia',
#  'Papua New Guinea',
#  'Solomon Islands',
#  'Vanuatu',
#  'Micronesia',
#  'Guam',
#  'Kiribati',
#  'Marshall Islands',
#  'Micronesia (Fed. States of)',
#  'Nauru',
#  'Northern Mariana Islands',
#  'Palau',
#  'Polynesia',
#  'American Samoa',
#  'Cook Islands',
#  'French Polynesia',
#  'Niue',
#  'Samoa',
#  'Tokelau',
#  'Tonga',
#  'Tuvalu',
#  'Wallis and Futuna Islands']

# %%
result33["Continent"]="None"
result31["Continent"]="None"

result31.head()
# Out:
#      Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0  Afghanistan       1996.0      8.471000e+07                 18.218528
# 1  Afghanistan       1997.0      1.530267e+08                 15.158800
# 2  Afghanistan       1998.0      2.553067e+08                 14.351002
# 3  Afghanistan       1999.0      2.446233e+08                 13.321431
# 4  Afghanistan       2000.0      2.410600e+08                 12.825481
#
#    Emigration per cap over all OECD  Emigration sum over all OECD countries  \
# 0                          0.000716                                 12765.0
# 1                          0.000715                                 13137.0
# 2                          0.000645                                 12173.0
# 3                          0.000613                                 11885.0
# 4                          0.000824                                 16550.0
#
#   Continent
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None

# %%
#we load in the dataframe for the 31 version
result=result31
result["Continent"][result["Recipient"].isin(asia)==True] = 'ASIA'
result["Continent"][result["Recipient"].isin(europe)==True] = 'EUROPE'
result["Continent"][result["Recipient"].isin(africa)==True] = 'AFRICA'
result["Continent"][result["Recipient"].isin(americas)==True] = 'AMERICA'
result["Continent"][result["Recipient"].isin(oceania)==True] = 'OCEANIA'
result["Continent"][result["Recipient"].isin(carribeans)==True] = 'CARRIBEANS'

result
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0     Afghanistan       1996.0      8.471000e+07                 18.218528
# 1     Afghanistan       1997.0      1.530267e+08                 15.158800
# 2     Afghanistan       1998.0      2.553067e+08                 14.351002
# 3     Afghanistan       1999.0      2.446233e+08                 13.321431
# 4     Afghanistan       2000.0      2.410600e+08                 12.825481
# 5     Afghanistan       2001.0      2.065400e+08                 10.633493
# 6     Afghanistan       2002.0      3.447067e+08                 16.830094
# 7     Afghanistan       2003.0      9.037933e+08                 41.875147
# 2555                                  2287.0    AFRICA
# 2556                                  2793.0    AFRICA
# 2557                                  4261.0    AFRICA
# 2558                                  3451.0    AFRICA
# 2559                                  3454.0    AFRICA
# 2560                                  3731.0    AFRICA
# 2561                                  3942.0    AFRICA
# 2562                                  4055.0    AFRICA
# 2563                                  4377.0    AFRICA
# 2564                                  4538.0    AFRICA
# 2565                                  5134.0    AFRICA
# 2566                                  3116.0    AFRICA
# 2567                                  2608.0    AFRICA
#
# [2549 rows x 7 columns]

# %%
result.to_csv("FinalData/MigrationVSMoney31_continents.csv", index=False)

# %%
#we load in the dataframe for the 33 version
result=result33
result["Continent"][result["Recipient"].isin(asia)==True] = 'ASIA'
result["Continent"][result["Recipient"].isin(europe)==True] = 'EUROPE'
result["Continent"][result["Recipient"].isin(africa)==True] = 'AFRICA'
result["Continent"][result["Recipient"].isin(americas)==True] = 'AMERICA'
result["Continent"][result["Recipient"].isin(oceania)==True] = 'OCEANIA'
result["Continent"][result["Recipient"].isin(carribeans)==True] = 'CARRIBEANS'

result33=result
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result.to_csv("FinalData/MigrationVSMoney33_continents.csv", index=False)

# %%
Oceania=pd.read_csv("Raw_data/Regions/oceania.csv", encoding="latin1", header=None)
Oceania=Oceania[0].tolist()
Carribeans=pd.read_csv("Raw_data/Regions/Carribeans.csv", encoding="latin1")
Carribeans=Carribeans["Caribbean"].tolist()
CentralAmerica=pd.read_csv("Raw_data/Regions/CentralAmerica.csv")
CentralAmerica=CentralAmerica["Central America"].tolist()
NorthernAmerica=pd.read_csv("Raw_data/Regions/NorthernAmerica.csv", header=None)
NorthernAmerica=NorthernAmerica[0].tolist()
SouthernAmerica=pd.read_csv("Raw_data/Regions/SouthernAmerica.csv", header=None)
SouthernAmerica=SouthernAmerica[0].tolist()
WesternEurope=pd.read_csv("Raw_data/Regions/WesternEurope.csv", header=None)
WesternEurope=WesternEurope[0].tolist()
SouthernEurope=pd.read_csv("Raw_data/Regions/SouthernEurope.csv", header=None)
SouthernEurope=SouthernEurope[0].tolist()
NorthernEurope=pd.read_csv("Raw_data/Regions/NorthernEurope.csv", header=None)
NorthernEurope=NorthernEurope[0].tolist()
EasternEurope=pd.read_csv("Raw_data/Regions/EasternEurope.csv", header=None)
EasternEurope=EasternEurope[0].tolist()
WesternAsia=pd.read_csv("Raw_data/Regions/WesternAsia.csv", header=None)
WesternAsia=WesternAsia[0].tolist()
SouthernEastAsia=pd.read_csv("Raw_data/Regions/SouthernEastAsia.csv", header=None)
SouthernEastAsia=SouthernEastAsia[0].tolist()
SouthernAsia=pd.read_csv("Raw_data/Regions/SouthernAsia.csv", header=None)
SouthernAsia=SouthernAsia[0].tolist()
CentralAsia=pd.read_csv("Raw_data/Regions/CentralAsia.csv", header=None)
CentralAsia=CentralAsia[0].tolist()
EasternAsia=pd.read_csv("Raw_data/Regions/EasternAsia.csv", header=None)
EasternAsia=EasternAsia[0].tolist()
WesternAfrica=pd.read_csv("Raw_data/Regions/WesternAfrica.csv", header=None, encoding="latin1")
WesternAfrica=WesternAfrica[0].tolist()
SouthernAfrica=pd.read_csv("Raw_data/Regions/SouthernAfrica.csv", header=None)
SouthernAfrica=SouthernAfrica[0].tolist()
EasternAfrica=pd.read_csv("Raw_data/Regions/EasternAfrica.csv", header=None, encoding="latin1")
EasternAfrica=EasternAfrica[0].tolist()
NorthernAfrica=pd.read_csv("Raw_data/Regions/NorthernAfrica.csv", header=None)
NorthernAfrica=NorthernAfrica[0].tolist()
MiddleAfrica=pd.read_csv("Raw_data/Regions/MiddleAfrica.csv", header=None)
MiddleAfrica=MiddleAfrica[0].tolist()
CentralAsia
# Out:
# ['Kazakhstan',
#  'Kyrgyzstan',
#  'Tajikistan',
#  'Turkmenistan',
#  'Uzbekistan',
#  'Uzbekistan']

# %%
result=result33
result["Region"]="None"
result["Region"][result["Recipient"].isin(Oceania)==True] = 'Oceania'
result["Region"][result["Recipient"].isin(Carribeans)==True] = 'Carribeans'
result["Region"][result["Recipient"].isin(CentralAmerica)==True] = 'CentralAmerica'
result["Region"][result["Recipient"].isin(NorthernAmerica)==True] = 'NorthernAmerica'
result["Region"][result["Recipient"].isin(SouthernAmerica)==True] = 'SouthernAmerica'
result["Region"][result["Recipient"].isin(WesternEurope)==True] = 'WesternEurope'
result["Region"][result["Recipient"].isin(NorthernEurope)==True] = 'NorthernEurope'
result["Region"][result["Recipient"].isin(EasternEurope)==True] = 'EasternEurope'
result["Region"][result["Recipient"].isin(SouthernEurope)==True] = 'SouthernEurope'
result["Region"][result["Recipient"].isin(WesternAsia)==True] = 'WesternAsia'
result["Region"][result["Recipient"].isin(CentralAsia)==True] = 'CentralAsia'
result["Region"][result["Recipient"].isin(SouthernEastAsia)==True] = 'SouthernEastAsia'
result["Region"][result["Recipient"].isin(SouthernAsia)==True] = 'SouthernAsia'
result["Region"][result["Recipient"].isin(EasternAsia)==True] = 'EasternAsia'
result["Region"][result["Recipient"].isin(WesternAfrica)==True] = 'WesternAfrica'
result["Region"][result["Recipient"].isin(SouthernAfrica)==True] = 'SouthernAfrica'
result["Region"][result["Recipient"].isin(EasternAfrica)==True] = 'EasternAfrica'
result["Region"][result["Recipient"].isin(NorthernAfrica)==True] = 'NorthernAfrica'
result["Region"][result["Recipient"].isin(MiddleAfrica)==True] = 'MiddleAfrica'

result33=result
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result=result31
result["Region"]="None"
result["Region"][result["Recipient"].isin(Oceania)==True] = 'Oceania'
result["Region"][result["Recipient"].isin(Carribeans)==True] = 'Carribeans'
result["Region"][result["Recipient"].isin(CentralAmerica)==True] = 'CentralAmerica'
result["Region"][result["Recipient"].isin(NorthernAmerica)==True] = 'NorthernAmerica'
result["Region"][result["Recipient"].isin(SouthernAmerica)==True] = 'SouthernAmerica'
result["Region"][result["Recipient"].isin(WesternEurope)==True] = 'WesternEurope'
result["Region"][result["Recipient"].isin(NorthernEurope)==True] = 'NorthernEurope'
result["Region"][result["Recipient"].isin(EasternEurope)==True] = 'EasternEurope'
result["Region"][result["Recipient"].isin(SouthernEurope)==True] = 'SouthernEurope'
result["Region"][result["Recipient"].isin(WesternAsia)==True] = 'WesternAsia'
result["Region"][result["Recipient"].isin(CentralAsia)==True] = 'CentralAsia'
result["Region"][result["Recipient"].isin(SouthernEastAsia)==True] = 'SouthernEastAsia'
result["Region"][result["Recipient"].isin(SouthernAsia)==True] = 'SouthernAsia'
result["Region"][result["Recipient"].isin(EasternAsia)==True] = 'EasternAsia'
result["Region"][result["Recipient"].isin(WesternAfrica)==True] = 'WesternAfrica'
result["Region"][result["Recipient"].isin(SouthernAfrica)==True] = 'SouthernAfrica'
result["Region"][result["Recipient"].isin(EasternAfrica)==True] = 'EasternAfrica'
result["Region"][result["Recipient"].isin(NorthernAfrica)==True] = 'NorthernAfrica'
result["Region"][result["Recipient"].isin(MiddleAfrica)==True] = 'MiddleAfrica'

result31=result
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result33.to_csv("FinalData/MigVsMoney_Cont_Reg33.csv", index=False)
result31.to_csv("FinalData/MigVsMoney_Cont_Reg31.csv", index=False)

result31
# Out:
#         Recipient  Report Year  3yrAverage Money  3yrAverage Money per cap  \
# 0     Afghanistan       1996.0      8.471000e+07                 18.218528
# 1     Afghanistan       1997.0      1.530267e+08                 15.158800
# 2     Afghanistan       1998.0      2.553067e+08                 14.351002
# 3     Afghanistan       1999.0      2.446233e+08                 13.321431
# 4     Afghanistan       2000.0      2.410600e+08                 12.825481
# 5     Afghanistan       2001.0      2.065400e+08                 10.633493
# 6     Afghanistan       2002.0      3.447067e+08                 16.830094
# 7     Afghanistan       2003.0      9.037933e+08                 41.875147
# 8     Afghanistan       2004.0      1.485807e+09                 66.674396
# 9     Afghanistan       2005.0      2.136387e+09                 92.325087
# 10    Afghanistan       2006.0      2.567073e+09                106.004533
# 11    Afghanistan       2007.0      2.983607e+09                119.014405
# 12    Afghanistan       2008.0      3.796883e+09                146.212038
# 13    Afghanistan       2009.0      4.323923e+09                162.096007
# 14    Afghanistan       2010.0      5.335007e+09                195.096638
# 15    Afghanistan       2011.0      5.796020e+09                206.323342
# 16    Afghanistan       2012.0      6.342863e+09                220.019689
# 17    Afghanistan       2013.0      6.331207e+09                213.132093
# 18    Afghanistan       2014.0      5.786667e+09                189.122901
# 19    Afghanistan       2015.0      5.204507e+09                164.683184
# 20        Albania       1996.0      3.049263e+09                 83.981712
# 21        Albania       1997.0      1.593693e+09                 74.249447
# 22        Albania       1998.0      2.326000e+08                 75.109423
# 23        Albania       1999.0      2.794933e+08                 90.238618
# 24        Albania       2000.0      4.084467e+08                131.396987
# 25        Albania       2001.0      4.926100e+08                158.139454
# 26        Albania       2002.0      5.121533e+08                164.182014
# 27        Albania       2003.0      4.402833e+08                141.071576
# 28        Albania       2004.0      4.295400e+08                137.794894
# 29        Albania       2005.0      4.111933e+08                132.211604
# ...           ...          ...               ...                       ...
# 2538       Zambia       2005.0      1.410953e+09                123.502450
# 2539       Zambia       2006.0      1.616637e+09                137.190246
# 2540       Zambia       2007.0      2.892270e+09                237.391317
# 2541       Zambia       2008.0      2.712440e+09                219.858334
